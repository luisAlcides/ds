# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df[df['size'] > 4]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 125       29.80  4.20  Female     No  Thur   Lunch     6
# 141       34.30  6.70    Male     No  Thur   Lunch     6
# 142       41.19  5.00    Male     No  Thur   Lunch     5
# 143       27.05  5.00  Female     No  Thur   Lunch     6
# 155       29.85  5.14  Female     No   Sun  Dinner     5
# 156       48.17  5.00    Male     No   Sun  Dinner     6
# 185       20.69  5.00    Male     No   Sun  Dinner     5
# 187       30.46  2.00    Male    Yes   Sun  Dinner     5
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5

# %%
sns.histplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.scatterplot(data=df, x='total_bill', y='tip', hue='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.boxplot(data=df, x='day', y='total_bill').set_title('Total Bill by day')
# Out:
# Text(0.5, 1.0, 'Total Bill by day')

# %%
matriz_corr = df.corr(numeric_only=True)

# %%
sns.heatmap(matriz_corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
precios = np.array([100, 200, 300])
precios
# Out:
# array([100, 200, 300])

# %%
precios_con_descuento = precios / 1.1
precios_con_descuento
# Out:
# array([ 90.90909091, 181.81818182, 272.72727273])

# %%
ventas = np.array([
    [10, 20],
    [5, 15],
    [30, 40]
])
ventas
# Out:
# array([[10, 20],
#        [ 5, 15],
#        [30, 40]])

# %%
ventas.sum(axis=1)
# Out:
# array([30, 20, 70])

# %%
arreglo_propinas = df['tip'].values
arreglo_propinas
# Out:
# array([ 1.01,  1.66,  3.5 ,  3.31,  3.61,  4.71,  2.  ,  3.12,  1.96,
#         3.23,  1.71,  5.  ,  1.57,  3.  ,  3.02,  3.92,  1.67,  3.71,
#         3.5 ,  3.35,  4.08,  2.75,  2.23,  7.58,  3.18,  2.34,  2.  ,
#         2.  ,  4.3 ,  3.  ,  1.45,  2.5 ,  3.  ,  2.45,  3.27,  3.6 ,
#         2.  ,  3.07,  2.31,  5.  ,  2.24,  2.54,  3.06,  1.32,  5.6 ,
#         3.  ,  5.  ,  6.  ,  2.05,  3.  ,  2.5 ,  2.6 ,  5.2 ,  1.56,
#         4.34,  3.51,  3.  ,  1.5 ,  1.76,  6.73,  3.21,  2.  ,  1.98,
#         3.76,  2.64,  3.15,  2.47,  1.  ,  2.01,  2.09,  1.97,  3.  ,
#         3.14,  5.  ,  2.2 ,  1.25,  3.08,  4.  ,  3.  ,  2.71,  3.  ,
#         3.4 ,  1.83,  5.  ,  2.03,  5.17,  2.  ,  4.  ,  5.85,  3.  ,
#         3.  ,  3.5 ,  1.  ,  4.3 ,  3.25,  4.73,  4.  ,  1.5 ,  3.  ,
#         1.5 ,  2.5 ,  3.  ,  2.5 ,  3.48,  4.08,  1.64,  4.06,  4.29,
#         3.76,  4.  ,  3.  ,  1.  ,  4.  ,  2.55,  4.  ,  3.5 ,  5.07,
# ...

# %%
edades = np.array([12, 25, 18, 40, 15, 30])
mayores_de_edad = edades[edades >= 18]
mayores_de_edad
# Out:
# array([25, 18, 40, 30])

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.scatterplot(data=df, x='total_bill', y='tip', ax=ax)
ax.set_xlabel('Monto de factura')
ax.set_ylabel('Propina')
# Out:
# Text(0, 0.5, 'Propina')

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Grafico 1 (Histograma)
sns.histplot(data=df, x='total_bill', ax=axes[0], color='skyblue')
axes[0].set_title('Distribucion de cuentas')

# Grafico 2 (Boxplot)
sns.boxplot(data=df, x='tip', ax=axes[1], color='salmon')
axes[1].set_title('Resumen de propinas')

plt.tight_layout()

# %%
df_puntas = pd.read_csv('puntas2025.csv')
df_puntas.head()
# Out:
#       Equipo Fecha_Inicial Fecha_Final  Horometro_Inicial  Horometro_Final  \
# 0  CQ-EXC-01    2025-05-12  2025-06-05             1016.8           1203.7
# 1  CQ-EXC-01    2025-06-05  2025-06-30             1203.7           1400.4
# 2  CQ-EXC-01    2025-06-30  2025-07-24             1400.4           1650.4
# 3  CQ-EXC-01    2025-07-24  2025-08-01             1650.4           1779.4
# 4  CQ-EXC-01    2025-08-01  2025-08-27             1779.4           2067.8
#
#    Rendimiento         Marca  Costos_Hora
# 0        186.9  CAT 597-6133     7.722204
# 1        196.7  CAT 597-6133     7.337468
# 2        250.0  CAT 597-6133     5.773120
# 3        129.0  CAT 597-6133    11.188217
# 4        288.4  CAT 597-6133     5.004438

# %%
df_puntas = df_puntas.dropna()
df_puntas
# Out:
#         Equipo Fecha_Inicial Fecha_Final  Horometro_Inicial  Horometro_Final  \
# 0    CQ-EXC-01    2025-05-12  2025-06-05             1016.8           1203.7
# 1    CQ-EXC-01    2025-06-05  2025-06-30             1203.7           1400.4
# 2    CQ-EXC-01    2025-06-30  2025-07-24             1400.4           1650.4
# 3    CQ-EXC-01    2025-07-24  2025-08-01             1650.4           1779.4
# 4    CQ-EXC-01    2025-08-01  2025-08-27             1779.4           2067.8
# ..         ...           ...         ...                ...              ...
# 102  CQ-EXC-10    2025-08-27  2025-10-06             1485.5           1683.7
# 103  CQ-EXC-10    2025-10-06  2025-10-29             1683.7           1859.2
# 104  CQ-EXC-10    2025-10-29  2025-12-03             1859.2           2000.6
# 105  CQ-EXC-10    2025-12-03  2025-12-12             2000.6           2093.9
# 106  CQ-EXC-10    2025-12-12  2025-12-18             2093.9           2137.0
#
#      Rendimiento         Marca  Costos_Hora
# ...

# %%
df_puntas['Gasto_total'] = df_puntas['Rendimiento'] * df_puntas['Costos_Hora']
df_puntas['Gasto_total']
df_puntas
# Out:
#         Equipo Fecha_Inicial Fecha_Final  Horometro_Inicial  Horometro_Final  \
# 0    CQ-EXC-01    2025-05-12  2025-06-05             1016.8           1203.7
# 1    CQ-EXC-01    2025-06-05  2025-06-30             1203.7           1400.4
# 2    CQ-EXC-01    2025-06-30  2025-07-24             1400.4           1650.4
# 3    CQ-EXC-01    2025-07-24  2025-08-01             1650.4           1779.4
# 4    CQ-EXC-01    2025-08-01  2025-08-27             1779.4           2067.8
# ..         ...           ...         ...                ...              ...
# 102  CQ-EXC-10    2025-08-27  2025-10-06             1485.5           1683.7
# 103  CQ-EXC-10    2025-10-06  2025-10-29             1683.7           1859.2
# 104  CQ-EXC-10    2025-10-29  2025-12-03             1859.2           2000.6
# 105  CQ-EXC-10    2025-12-03  2025-12-12             2000.6           2093.9
# 106  CQ-EXC-10    2025-12-12  2025-12-18             2093.9           2137.0
#
# ...

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=df_puntas, x='Equipo', y='Rendimiento', estimator='mean', errorbar=None)
plt.title('Rendimiento por equipos')
plt.xticks(rotation=90)
plt.show()

# %%
ax = sns.barplot(data=df_puntas, x='Marca', y='Rendimiento', estimator='mean', errorbar=None)
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', label_type='edge', fontsize=10, color='black', weight='bold')

# %%
plt.figure(figsize=(10, 6))

ax = sns.barplot(data=df_puntas, x='Marca', y='Rendimiento', palette='viridis', errorbar=None)

sns.stripplot(data=df_puntas, x='Marca', y='Rendimiento', color='black', alpha=0.3, ax=ax)

for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', padding=3, weight='bold')

plt.title('Rendimiento promedio y dispersion por marca de repuesto')
plt.xticks(rotation=15)
plt.show()
# Out:
# C:\Users\PC01\AppData\Local\Temp\ipykernel_14836\795168101.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=df_puntas, x='Marca', y='Rendimiento', palette='viridis', errorbar=None)

# %%
df_puntas['Marca'] = df_puntas['Marca'].replace('CAT 539-5692-1', 'CAT 539-5652-01')

# %%
plt.figure(figsize=(10, 6))

ax = sns.barplot(data=df_puntas, x='Marca', y='Rendimiento', errorbar=None)

sns.stripplot(data=df_puntas, x='Marca', y='Rendimiento', color='black', alpha=0.5, ax=ax)

for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', padding=3, weight='bold')

plt.title('Rendimiento promedio y dispersion por marca de repuesto')
plt.xticks(rotation=15)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Preparación y Limpieza (Paso Crucial)
# Reemplazamos la marca duplicada
df_puntas['Marca'] = df_puntas['Marca'].replace('CAT 539-5692', 'CAT 539-5652-01')

# Ordenamos por rendimiento promedio para facilitar la lectura
order = df_puntas.groupby('Marca')['Rendimiento'].mean().sort_values(ascending=False).index

# 2. Configuración Estética
sns.set_theme(style="whitegrid", context="talk") 
plt.figure(figsize=(12, 7))

# 3. Creación del Gráfico
ax = sns.barplot(
    data=df_puntas, x='Marca', y='Rendimiento', 
    palette='viridis', errorbar=None, order=order, alpha=0.8
)

# Añadimos los puntos individuales (Stripplot) con transparencia para ver la densidad
sns.stripplot(
    data=df_puntas, x='Marca', y='Rendimiento', 
    color='0.3', alpha=0.4, ax=ax, order=order, jitter=True
)

# 4. Etiquetas de Datos Profesionales
for container in ax.containers:
    ax.bar_label(container, fmt='%.1f', padding=5, weight='bold', fontsize=12)

# 5. Detalles Finales (Títulos y Ejes)
sns.despine(left=True, bottom=True)
plt.title('Comparativa de Rendimiento por Marca de Repuesto', fontsize=18, pad=20, weight='bold')
plt.xlabel('Código de Marca / Repuesto', fontsize=14, labelpad=15)
plt.ylabel('Rendimiento Promedio (Horas)', fontsize=14, labelpad=15)
plt.xticks(rotation=10)

# 6. Guardado en Alta Calidad
plt.savefig('reporte_rendimiento.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\PC01\AppData\Local\Temp\ipykernel_14836\3216431558.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(
